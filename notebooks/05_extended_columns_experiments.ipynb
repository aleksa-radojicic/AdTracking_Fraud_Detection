# %% [markdown]
# # Extended Columns Experiments

# %%
import os

os.chdir("..")

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import polars as pl

from src.constants import RANDOM_STATE
from src.datatypes import BaseSchema, ExtendedSchema, TrainSchema, filepaths

# %%
# Alias
S = TrainSchema
E = ExtendedSchema

train_schema = BaseSchema.__annotations__ | TrainSchema.__annotations__

# %%
train = pl.read_parquet(filepaths.train_subset, schema=train_schema)
train = train.cast({S.click_time: pl.Datetime('ms')})
train = train.sort([S.ip, S.click_time], maintain_order=True)

test = pl.read_parquet(filepaths.test_subset, schema=train_schema)
test = test.cast({S.click_time: pl.Datetime('ms')})
test = test.sort([S.ip, S.click_time], maintain_order=True)

# %%
X_train: pl.DataFrame = train.drop(S.attributed_time, S.label())
X_test: pl.DataFrame = test.drop(S.attributed_time, S.label())

y_train: pl.DataFrame = train.select(S.label())
y_test: pl.DataFrame = test.select(S.label())

# %%
from src.feature_engineering import make_derived_columns

X_train_processed = make_derived_columns(X_train)
X_test_processed = (
    X_train.with_columns(is_train=True)
    .vstack(
        X_test.with_columns(is_train=False))
    .pipe(make_derived_columns)
    .filter(pl.col('is_train').eq(False))
    .drop('is_train')
)

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import FunctionTransformer, Pipeline
from sklearn.preprocessing import OrdinalEncoder


ordinal_columns = [S.ip, S.app, S.device, S.os, S.channel, E.click_counts_group]
no_op_columns = list(ExtendedSchema.__annotations__.keys())
no_op_columns.remove(E.click_counts_group)

ct_ordinal = ColumnTransformer(
    [
        # NOTE: Needs readjustments to be used in a pipeline
        # column_extender = FunctionTransformer(func=make_derived_columns)
        ("raw", FunctionTransformer(), no_op_columns),
        ("ordinal_encoder", OrdinalEncoder(min_frequency=0.000008, unknown_value=-1, handle_unknown='use_encoded_value', dtype=np.int16), ordinal_columns),
    ]
)

pipeline = Pipeline(
    [
        # ("column_extender", column_extender),
        ("column_transformer", ct_ordinal),
    ]
)
pipeline.set_output(transform='polars')
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('raw', FunctionTransformer(),
#                                                   ['click_timestamp',
#                                                    'previous_sessions',
#                                                    'total_sessions',
#                                                    'current_session_duration_till_now',
#                                                    'current_session_duration',
#                                                    'avg_previous_sessions_duration']),
#                                                  ('ordinal_encoder',
#                                                   OrdinalEncoder(dtype=<class 'numpy.int16'>,
#                                                                  handle_unknown='use_encoded_value',
#                                                                  min_frequency=8e-06,
#                                                                  unknown_value=-1),
#                                                   ['ip', 'app', 'device', 'os',
#                                                    'channel',
#                                                    'click_counts_group'])]))])

# %%
pipeline.fit(X_train_processed, y_train)
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('raw', FunctionTransformer(),
#                                                   ['click_timestamp',
#                                                    'previous_sessions',
#                                                    'total_sessions',
#                                                    'current_session_duration_till_now',
#                                                    'current_session_duration',
#                                                    'avg_previous_sessions_duration']),
#                                                  ('ordinal_encoder',
#                                                   OrdinalEncoder(dtype=<class 'numpy.int16'>,
#                                                                  handle_unknown='use_encoded_value',
#                                                                  min_frequency=8e-06,
#                                                                  unknown_value=-1),
#                                                   ['ip', 'app', 'device', 'os',
#                                                    'channel',
#                                                    'click_counts_group'])]))])

# %% [markdown]
# # Experiment 1: Default hyperparameters

# %%
MIN_SAMPLES_LEAF = 20

# %%
from sklearn.base import BaseEstimator
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from src.utils import do_experiment

classifiers_1: dict[str, tuple[Pipeline, BaseEstimator]] = {
    "DecisionTree": (pipeline, DecisionTreeClassifier(min_samples_leaf=MIN_SAMPLES_LEAF, random_state=RANDOM_STATE)),
    "RandomForest": (pipeline, RandomForestClassifier(
        min_samples_leaf=MIN_SAMPLES_LEAF, n_estimators=100, random_state=RANDOM_STATE, n_jobs=-1,
    )),
    "AdaBoost": (pipeline, AdaBoostClassifier(
        n_estimators=50, random_state=RANDOM_STATE,
    )),
}

experiment_1_results = do_experiment(classifiers_1, X_train_processed, X_test_processed, y_train, y_test)
print(pl.DataFrame(experiment_1_results))
# Out:
# Training DecisionTree...
# {'Classifier': 'DecisionTree', 'AUC (Train)': 0.9983240898, 'AUC (Test)': 0.8699518347, 'Time taken': 11.787395455001388}
#
# Training RandomForest...
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# {'Classifier': 'RandomForest', 'AUC (Train)': 0.9979594398, 'AUC (Test)': 0.9294157261, 'Time taken': 42.62628782200045}
#
# Training AdaBoost...
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'Classifier': 'AdaBoost', 'AUC (Train)': 0.9545548573, 'AUC (Test)': 0.915544108, 'Time taken': 31.209515256006853}
#
# shape: (3, 4)
# ┌──────────────┬─────────────┬────────────┬────────────┐
# │ Classifier   ┆ AUC (Train) ┆ AUC (Test) ┆ Time taken │
# │ ---          ┆ ---         ┆ ---        ┆ ---        │
# │ str          ┆ f64         ┆ f64        ┆ f64        │
# ╞══════════════╪═════════════╪════════════╪════════════╡
# │ DecisionTree ┆ 0.998324    ┆ 0.869952   ┆ 11.787395  │
# │ RandomForest ┆ 0.997959    ┆ 0.929416   ┆ 42.626288  │
# │ AdaBoost     ┆ 0.954555    ┆ 0.915544   ┆ 31.209515  │
# └──────────────┴─────────────┴────────────┴────────────┘

# %%
experiment_1_results[0]['Hyperparameters'] = 'min_samples_leaf=20'
experiment_1_results[1]['Hyperparameters'] = 'min_samples_leaf=20, n_estimators=100'
experiment_1_results[2]['Hyperparameters'] = 'n_estimators=50'

# %% [markdown]
# # Experiment 2: Default hyperparameters 2x

# %%
classifiers_2: dict[str, tuple[Pipeline, BaseEstimator]] = {
    "RandomForest": (pipeline, RandomForestClassifier(
        min_samples_leaf=MIN_SAMPLES_LEAF, n_estimators=200, random_state=RANDOM_STATE, n_jobs=-1,
    )),
    "AdaBoost": (pipeline, AdaBoostClassifier(
        n_estimators=100, random_state=RANDOM_STATE,
    )),
}

experiment_2_results = do_experiment(classifiers_2, X_train_processed, X_test_processed, y_train, y_test)
print(pl.DataFrame(experiment_2_results))
# Out:
# Training RandomForest...
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# {'Classifier': 'RandomForest', 'AUC (Train)': 0.997983429, 'AUC (Test)': 0.9302313097, 'Time taken': 78.75347944498935}
#
# Training AdaBoost...
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'Classifier': 'AdaBoost', 'AUC (Train)': 0.9595870816, 'AUC (Test)': 0.9235379809, 'Time taken': 58.09987184200145}
#
# shape: (2, 4)
# ┌──────────────┬─────────────┬────────────┬────────────┐
# │ Classifier   ┆ AUC (Train) ┆ AUC (Test) ┆ Time taken │
# │ ---          ┆ ---         ┆ ---        ┆ ---        │
# │ str          ┆ f64         ┆ f64        ┆ f64        │
# ╞══════════════╪═════════════╪════════════╪════════════╡
# │ RandomForest ┆ 0.997983    ┆ 0.930231   ┆ 78.753479  │
# │ AdaBoost     ┆ 0.959587    ┆ 0.923538   ┆ 58.099872  │
# └──────────────┴─────────────┴────────────┴────────────┘

# %%
experiment_2_results[0]['Hyperparameters'] = 'min_samples_leaf=20, n_estimators=200'
experiment_2_results[1]['Hyperparameters'] = 'n_estimators=100'

# %% [markdown]
# # Experiment 3: Default hyperparameters 3x

# %%
classifiers_3: dict[str, tuple[Pipeline, BaseEstimator]] = {
    "RandomForest": (pipeline, RandomForestClassifier(
        min_samples_leaf=MIN_SAMPLES_LEAF, n_estimators=300, random_state=RANDOM_STATE, n_jobs=-1,
    )),
    "AdaBoost": (pipeline, AdaBoostClassifier(
        n_estimators=150, random_state=RANDOM_STATE,
    )),
}

experiment_3_results = do_experiment(classifiers_3, X_train_processed, X_test_processed, y_train, y_test)
print(pl.DataFrame(experiment_3_results))
# Out:
# Training RandomForest...
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# {'Classifier': 'RandomForest', 'AUC (Train)': 0.9980083676, 'AUC (Test)': 0.9300665306, 'Time taken': 118.58249692698882}
#
# Training AdaBoost...
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'Classifier': 'AdaBoost', 'AUC (Train)': 0.9627458364, 'AUC (Test)': 0.9299404947, 'Time taken': 89.68292627501069}
#
# shape: (2, 4)
# ┌──────────────┬─────────────┬────────────┬────────────┐
# │ Classifier   ┆ AUC (Train) ┆ AUC (Test) ┆ Time taken │
# │ ---          ┆ ---         ┆ ---        ┆ ---        │
# │ str          ┆ f64         ┆ f64        ┆ f64        │
# ╞══════════════╪═════════════╪════════════╪════════════╡
# │ RandomForest ┆ 0.998008    ┆ 0.930067   ┆ 118.582497 │
# │ AdaBoost     ┆ 0.962746    ┆ 0.92994    ┆ 89.682926  │
# └──────────────┴─────────────┴────────────┴────────────┘

# %%
experiment_3_results[0]['Hyperparameters'] = 'min_samples_leaf=20, n_estimators=300'
experiment_3_results[1]['Hyperparameters'] = 'n_estimators=150'

# %% [markdown]
# # Experiment 4: Default hyperparameters 4x

# %%
classifiers_4: dict[str, tuple[Pipeline, BaseEstimator]] = {
    "RandomForest": (pipeline, RandomForestClassifier(
        min_samples_leaf=MIN_SAMPLES_LEAF, n_estimators=400, random_state=RANDOM_STATE, n_jobs=-1,
    )),
    "AdaBoost": (pipeline, AdaBoostClassifier(
        n_estimators=200, random_state=RANDOM_STATE,
    )),
}

experiment_4_results = do_experiment(classifiers_4, X_train_processed, X_test_processed, y_train, y_test)
print(pl.DataFrame(experiment_4_results))
# Out:
# Training RandomForest...
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# {'Classifier': 'RandomForest', 'AUC (Train)': 0.9980067714, 'AUC (Test)': 0.9316766602, 'Time taken': 155.92264207699918}
#
# Training AdaBoost...
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'Classifier': 'AdaBoost', 'AUC (Train)': 0.9649161616, 'AUC (Test)': 0.9339805108, 'Time taken': 136.0032646049949}
#
# shape: (2, 4)
# ┌──────────────┬─────────────┬────────────┬────────────┐
# │ Classifier   ┆ AUC (Train) ┆ AUC (Test) ┆ Time taken │
# │ ---          ┆ ---         ┆ ---        ┆ ---        │
# │ str          ┆ f64         ┆ f64        ┆ f64        │
# ╞══════════════╪═════════════╪════════════╪════════════╡
# │ RandomForest ┆ 0.998007    ┆ 0.931677   ┆ 155.922642 │
# │ AdaBoost     ┆ 0.964916    ┆ 0.933981   ┆ 136.003265 │
# └──────────────┴─────────────┴────────────┴────────────┘

# %%
experiment_4_results[0]['Hyperparameters'] = 'min_samples_leaf=20, n_estimators=400'
experiment_4_results[1]['Hyperparameters'] = 'n_estimators=200'

# %%
for i, _experiment in enumerate((experiment_1_results, experiment_2_results, experiment_3_results, experiment_4_results), start=1):
    for a in _experiment:
        a['Experiment'] = i

# %% [markdown]
# # Save experiments

# %%
used_columns = ordinal_columns + no_op_columns

# %%
experiments = pl.concat((
    pl.DataFrame(experiment_1_results).select('Experiment', pl.all().exclude('Experiment')), 
    pl.DataFrame(experiment_2_results).select('Experiment', pl.all().exclude('Experiment')), 
    pl.DataFrame(experiment_3_results).select('Experiment', pl.all().exclude('Experiment')), 
    pl.DataFrame(experiment_4_results).select('Experiment', pl.all().exclude('Experiment')), 
))
experiments = experiments.with_columns(
    pl.all(), used_columns=pl.lit(", ".join(used_columns)), preprocessing=pl.lit("min_frequency=0.000008, unknown_value=-1, handle_unknown='use_encoded_value', dtype=np.int16")
)
experiments
# Out:
# shape: (9, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ Experiment ┆ Classifier ┆ AUC        ┆ AUC       ┆ Time      ┆ Hyperpara ┆ used_colu ┆ preproces │
# │ ---        ┆ ---        ┆ (Train)    ┆ (Test)    ┆ taken     ┆ meters    ┆ mns       ┆ sing      │
# │ i64        ┆ str        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆ f64        ┆ f64       ┆ f64       ┆ str       ┆ str       ┆ str       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1          ┆ DecisionTr ┆ 0.998324   ┆ 0.869952  ┆ 11.787395 ┆ min_sampl ┆ ip, app,  ┆ min_frequ │
# │            ┆ ee         ┆            ┆           ┆           ┆ es_leaf=2 ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆ 0         ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆           ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# │ 1          ┆ RandomFore ┆ 0.997959   ┆ 0.929416  ┆ 42.626288 ┆ min_sampl ┆ ip, app,  ┆ min_frequ │
# │            ┆ st         ┆            ┆           ┆           ┆ es_leaf=2 ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆ 0, n_esti ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆ mat…      ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# │ 1          ┆ AdaBoost   ┆ 0.954555   ┆ 0.915544  ┆ 31.209515 ┆ n_estimat ┆ ip, app,  ┆ min_frequ │
# │            ┆            ┆            ┆           ┆           ┆ ors=50    ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆           ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆           ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# │ 2          ┆ RandomFore ┆ 0.997983   ┆ 0.930231  ┆ 78.753479 ┆ min_sampl ┆ ip, app,  ┆ min_frequ │
# │            ┆ st         ┆            ┆           ┆           ┆ es_leaf=2 ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆ 0, n_esti ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆ mat…      ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# │ 2          ┆ AdaBoost   ┆ 0.959587   ┆ 0.923538  ┆ 58.099872 ┆ n_estimat ┆ ip, app,  ┆ min_frequ │
# │            ┆            ┆            ┆           ┆           ┆ ors=100   ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆           ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆           ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# │ 3          ┆ RandomFore ┆ 0.998008   ┆ 0.930067  ┆ 118.58249 ┆ min_sampl ┆ ip, app,  ┆ min_frequ │
# │            ┆ st         ┆            ┆           ┆ 7         ┆ es_leaf=2 ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆ 0, n_esti ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆ mat…      ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# │ 3          ┆ AdaBoost   ┆ 0.962746   ┆ 0.92994   ┆ 89.682926 ┆ n_estimat ┆ ip, app,  ┆ min_frequ │
# │            ┆            ┆            ┆           ┆           ┆ ors=150   ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆           ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆           ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# │ 4          ┆ RandomFore ┆ 0.998007   ┆ 0.931677  ┆ 155.92264 ┆ min_sampl ┆ ip, app,  ┆ min_frequ │
# │            ┆ st         ┆            ┆           ┆ 2         ┆ es_leaf=2 ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆ 0, n_esti ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆ mat…      ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# │ 4          ┆ AdaBoost   ┆ 0.964916   ┆ 0.933981  ┆ 136.00326 ┆ n_estimat ┆ ip, app,  ┆ min_frequ │
# │            ┆            ┆            ┆           ┆ 5         ┆ ors=200   ┆ device,   ┆ ency=0.00 │
# │            ┆            ┆            ┆           ┆           ┆           ┆ os,       ┆ 0008,     │
# │            ┆            ┆            ┆           ┆           ┆           ┆ channel,  ┆ unknow…   │
# │            ┆            ┆            ┆           ┆           ┆           ┆ …         ┆           │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘

# %%
from pathlib import Path

experiments_fp = Path("experiments/05_extended_columns.csv")
experiments_fp.parent.mkdir(parents=True, exist_ok=True)

experiments.write_csv(experiments_fp)

# %% [markdown]
# # Feature importance for AdaBoost250, AdaBoost500, RandomForest400 & RandomForest500

# %%
ada150_df = pl.DataFrame({
    "importance": classifiers_3['AdaBoost'][1].feature_importances_, 
    "feature": classifiers_3['AdaBoost'][1].feature_names_in_}
)
ada200_df = pl.DataFrame({
    "importance": classifiers_4['AdaBoost'][1].feature_importances_, 
    "feature": classifiers_4['AdaBoost'][1].feature_names_in_},
)
rf200_df = pl.DataFrame({
    "importance": classifiers_3['RandomForest'][1].feature_importances_, 
    "feature": classifiers_3['RandomForest'][1].feature_names_in_}
)
rf300_df = pl.DataFrame({
    "importance": classifiers_4['RandomForest'][1].feature_importances_, 
    "feature": classifiers_4['RandomForest'][1].feature_names_in_}
)

combined_last_two_experiments_df = pl.concat([
    rf300_df.with_columns(pl.lit('RandomForest500').alias('classifier')),
    rf200_df.with_columns(pl.lit('RandomForest400').alias('classifier')),
    ada200_df.with_columns(pl.lit('AdaBoost500').alias('classifier')),
    ada150_df.with_columns(pl.lit('AdaBoost250').alias('classifier')),
])
combined_last_two_experiments_df.plot.bar(x="importance:Q", y="feature:N", color='classifier:N', yOffset='classifier:N').properties(width=700, height=500)
# Out:
# alt.Chart(...)
