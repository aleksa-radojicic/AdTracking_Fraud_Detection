# %% [markdown]
# # Hyperparameters Tuning

# %%
import os

os.chdir("..")

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import polars as pl

from src.constants import MIN_SAMPLES_LEAF, RANDOM_STATE
from src.datatypes import BaseSchema, ExtendedSchema, TrainSchema, filepaths

# %%
# Alias
S = TrainSchema
E = ExtendedSchema

train_schema = BaseSchema.__annotations__ | TrainSchema.__annotations__

# %%
train = pl.read_parquet(filepaths.train_subset, schema=train_schema)
train = train.cast({S.click_time: pl.Datetime('ms')})
train = train.sort([S.ip, S.click_time], maintain_order=True)

test = pl.read_parquet(filepaths.test_subset, schema=train_schema)
test = test.cast({S.click_time: pl.Datetime('ms')})
test = test.sort([S.ip, S.click_time], maintain_order=True)

# %%
X_train: pl.DataFrame = train.drop(S.attributed_time, S.label())
X_test: pl.DataFrame = test.drop(S.attributed_time, S.label())

y_train: pl.DataFrame = train.select(S.label())
y_test: pl.DataFrame = test.select(S.label())

# %%
from src.feature_engineering import make_derived_columns


X_train_processed = make_derived_columns(X_train)
X_test_processed = (
    X_train.with_columns(is_train=True)
    .vstack(
        X_test.with_columns(is_train=False))
    .pipe(make_derived_columns)
    .filter(pl.col('is_train').eq(False))
    .drop('is_train')
)

# %%
import numpy as np
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import FunctionTransformer, Pipeline
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import roc_auc_score

ordinal_columns = [S.ip, S.app, S.device, S.os, S.channel, E.click_counts_group]
no_op_columns = list(ExtendedSchema.__annotations__.keys())
no_op_columns.remove(E.click_counts_group)
used_columns = ordinal_columns + no_op_columns
print(f"Used columns: {used_columns}")

ct_ordinal = ColumnTransformer(
    [
        ("raw", FunctionTransformer(), no_op_columns),
        ("ordinal_encoder", OrdinalEncoder(min_frequency=0.000008, unknown_value=-1, handle_unknown='use_encoded_value', dtype=np.int16), ordinal_columns),
    ]
)

pipeline = Pipeline(
    [
        ("column_transformer", ct_ordinal),
    ]
)
pipeline.set_output(transform='polars');
# Out:
# Used columns: ['ip', 'app', 'device', 'os', 'channel', 'click_counts_group', 'click_timestamp', 'previous_sessions', 'total_sessions', 'current_session_duration_till_now', 'current_session_duration', 'avg_previous_sessions_duration']

# %%
model_rf = RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=-1)

param_grid = {
    "n_estimators": [300, 400],
    "max_depth": [6, 10, None],
    "max_features": ['sqrt', len(used_columns) // 2, len(used_columns)],
    "min_samples_leaf": [MIN_SAMPLES_LEAF],
}

# %%
pipeline.fit(X_train_processed, y_train)

X_train_processed = pipeline.transform(X_train_processed)
X_test_processed = pipeline.transform(X_test_processed)

# %%
from dataclasses import asdict, dataclass, field
from sklearn import clone
from sklearn.model_selection import ParameterGrid


N_DIGITS = 10


@dataclass(kw_only=True)
class ExperimentResult:
    hyperparameters: dict
    train_auc: float
    test_auc: float
    model: RandomForestClassifier = field(repr=False)


experiment_results: list[ExperimentResult] = []

for _hyperparams in ParameterGrid(param_grid):
    print(f"Training model with hyperparameters: {_hyperparams}")
    _model: RandomForestClassifier = clone(model_rf)
    _model.set_params(**_hyperparams)

    _model.fit(X_train_processed, y_train)

    y_train_proba = _model.predict_proba(X_train_processed)[:, 1]
    y_test_proba  = _model.predict_proba(X_test_processed)[:, 1]

    _train_auc: float = round(roc_auc_score(y_train, y_train_proba), N_DIGITS)
    _test_auc: float = round(roc_auc_score(y_test,  y_test_proba), N_DIGITS)

    _experiment = ExperimentResult(
        hyperparameters=_hyperparams,
        train_auc=_train_auc,
        test_auc=_test_auc,
        model=_model
    )
    print(f"Current run finished:\n{_experiment}")
    experiment_results.append(_experiment)
    
experiment_results = sorted(experiment_results, key=lambda x: x.test_auc, reverse=True)
best_experiment = experiment_results[0]
print(f"Best experiment:]n{best_experiment}")
# Out:
# Training model with hyperparameters: {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 20, 'n_estimators': 300}
# /home/aleksa/Projects/AdTracking_Fraud_Detection/.venv/lib/python3.13/site-packages/sklearn/base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Current run finished:
# ExperimentResult(hyperparameters={'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 20, 'n_estimators': 300}, train_auc=0.9517110846, test_auc=0.9238471199)
# Training model with hyperparameters: {'max_depth': 6, 'max_features': 'sqrt', 'min_samples_leaf': 20, 'n_estimators': 400}
# ...

# %% [markdown]
# # Save best model

# %%
from pathlib import Path
import joblib

model_best = best_experiment.model
model_filepath = Path("models/rf_model.joblib")
model_filepath.parent.mkdir(parents=True, exist_ok=True)

joblib.dump(model_best, model_filepath, compress=3);

# %% [markdown]
# # Save results

# %%
import json

param_grid_filepath = Path("experiments/06_param_grid_rf.json")
tuning_results_filepath = Path("experiments/06_tuning_results_rf.csv")

# Save param_grid
with open(param_grid_filepath, 'w') as json_file:
    json.dump(param_grid, json_file, indent=2)

# Save tuning results
df_results = pl.DataFrame([asdict(exp) for exp in experiment_results])
df_results = df_results.with_columns(pl.col('hyperparameters').struct.json_encode())
df_results = df_results.drop('model')
df_results.write_csv(tuning_results_filepath)

# %% [markdown]
# # ROC curve

# %%
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, y_test_proba)

roc_data = pl.DataFrame({
    'False Positive Rate': fpr,
    'True Positive Rate': tpr,
    'Thresholds': thresholds
})

# %%
import altair as alt

alt.data_transformers.enable('default', max_rows=None)
roc_chart = alt.Chart(roc_data).mark_line(color='blue').encode(
    x='False Positive Rate',
    y='True Positive Rate',
    tooltip=['False Positive Rate', 'True Positive Rate']
).properties(
    title=f'Receiver Operating Characteristic (ROC) Curve (AUC = {best_experiment.test_auc:.4f})',
    width=600,
    height=400
)

diagonal = alt.Chart(pl.DataFrame({'x': [0, 1], 'y': [0, 1]})).mark_line(color='red', strokeDash=[5, 5]).encode(
    x='x',
    y='y'
)

final_chart = roc_chart + diagonal
final_chart.configure_axis(
    grid=False
).configure_view(
    strokeWidth=0
).show()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Feature importances

# %%
from matplotlib import pyplot as plt

sorted_feat_importances = sorted(zip(model_best.feature_importances_, model_best.feature_names_in_))

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.barh([feat for _, feat in sorted_feat_importances], [imp for imp, _ in sorted_feat_importances])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances for optimized Random Forest')
plt.show()
